# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set the API endpoint and parameters
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "36.1627,-86.7816",
    "radius": 48280,
    "keyword": "grocery store",
    "limit": 100,
    "key": "AIzaSyBxCevn29vIjZ-yDlyeW4ggguX5d_pcSh4"
}

# Send GET requests and retrieve all results
results = []
next_page_token = None

while True:
    if next_page_token:
        params["pagetoken"] = next_page_token

    response = requests.get(url, params=params)
    data = response.json()
    results.extend(data["results"])

    next_page_token = data.get("next_page_token")
    if not next_page_token:
        break

# Create a DataFrame from the results
pageone_df = pd.DataFrame(columns=["Name", "Address"])

for result in results:
    name = result["name"]
    address = result["vicinity"]

    pageone_df = pd.concat([pageone_df, pd.DataFrame({"Name": [name], "Address": [address]})], ignore_index=True)

# Display the DataFrame
pageone_df
# Out:
#                            Name                                      Address
# 0      Garden Fresh Food Market                  800 Madison Square, Madison
# 1          H G Hill Food Stores               3105 Dickerson Pike, Nashville
# 2                     Food Lion              11459 Old Nashville Hwy, Smyrna
# 3                  Trader Joe's               3909 Hillsboro Pike, Nashville
# 4              The Fresh Market                   235 Franklin Rd, Brentwood
# 5   Walmart Neighborhood Market               5531 Edmondson Pike, Nashville
# 6                     Food Lion                     936 Richards Rd, Antioch
# 7         Downtown Fresh Market                     531 4th Ave S, Nashville
# 8                        Kroger                   2201 21st Ave S, Nashville
# 9                     Food Lion                      3636 Bell Rd, Nashville
# 10           Whole Foods Market                     1202 Broadway, Nashville
# ...

# %%
response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{\n   "html_attributions" : [],\n   "next_page_token" : "AZose0kr8O3Q6kvGVVoITdxFrDj34MgpLbqAhvHaRhw6EdkmRvJupWJd7ZDFkxGaH2_XNsKjla-ykN5vP8lJfB7LlqiRQBc6gXpfO-ME-jMKOZrBHtjZDWhM8F698PNgivNxp_Eoh7WuqZs-2cnhzVW_C0jjqJrukoH_Pnre2rB0K9U462n2BGnU8d_4YeO3E2Vm7pI5rUs9JhTs3KSPPSR2aR49bGU0QQ1pfmlvIY3Yu_MfVtruU1TjzxZxt-ljmkVJfgeFdWWeW5UiqikRILo5dbqAv6UQQVq5_qx3745w5ug0Qs1X_qkzStacdkBgYvMmHJojOPaXbfdr00wUWHwTUOBAiylBTFFGSUmsCjZMMwr5iW1uRRgw0N-TuvQpmqQDt0D2SRF16ZhBfWN9A2JcR8by1sEf4EyAAjgJhlo2TJ_0K9pVL8Nlv_Cisn9cqgn5sVM26U1IKUH213hdVoDthTDl2iH7RWYrXtVcuRA9LkY46s1RaQ-j-jtkHYyqVgZsE3Xcg--giqyZHl1lVcByOFJZyKJ8gBDuTV634xCDyJgTiSc3oDHBY0M_Ma4UhV3o8NCHulxtYyBKhAhkGMwjHTB6wUjzQTPPKO5dL3X5a_CZE79T4oOCec6VAlfhgpv9mwAu0WasF2hiv6KkWJhrSA",\n   "results" : [\n      {\n         "business_status" : "OPERATIONAL",\n         "geometry" : {\n            "location" : {\n               "lat" : 36.1844297,\n               "lng" : -86.7468566\n            },\n            "viewport" : {\n               "northeast" :
# ...

# %%
# Set the API endpoint and parameters
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "36.1627,-86.7816",
    "radius": 48280,
    "keyword": "grocery store",
    "limit": 100,
    "key": "AIzaSyBxCevn29vIjZ-yDlyeW4ggguX5d_pcSh4",
    "pagetoken": "AZose0lvAEdZj-EY4detg1Im6kuAW_GdSxIoAOIaoPcYm0zHCnv9QGNpkQ48Pc3Kfdl_la688ftaaPn4-PU8nSKfPn5aGRx7bjdB-FVcJnz7zDrJvIRyXgcojZjkkXRKpK43L8zLPeTL7Xl8u_4RiwAxlwKcmduStDfmk19PevhipBFNLEiBs75qdmV006X3DbE3oQUPYuWYrBLJy4uhXgs7KABFPFI-1J4FQVgeGGhh7ogM2ccJSevO8rznM8NCE_siVpuYYAAuhTNRgmtDOhov5VQ8l2FIaLZGcv2NEN6HtCNr2ILcEHTnLdaTOEz1IYg0ExfC39BcMpiomTK_OBJ3Pk0Dqm8xt6JXvxUTtWBs56INPOEDNhPN9SqYhqhbeTgyDWPtYeuZ1YSS-p3XQRRR5WytCohkv_CxCJF1PEOfnK6KcIbvMKglGuD4fgSlwbwFVX-Xi4J7befbPZT0QLGamicg4VHN5RKP3D03BWiA0gnGQWlnUf0DsMxA396M3dy-JqNZh7nHYEanMnyLqciU9aXPHjnyD9uVxOtecN49Lrw5x79tniYlb8tSZPmhxno6kldRyiHqyNS8ZUm1FhDJbKKSojjAOqoeuQsaBkQL8YyySvlBkwHwW3Mv9ZpTY_XTtEisiB-_phNxa2FG2A_8iw"
}

# Send GET requests and retrieve all results
results = []
next_page_token = None

while True:
    if next_page_token:
        params["pagetoken"] = next_page_token

    response = requests.get(url, params=params)
    data = response.json()
    results.extend(data["results"])

    next_page_token = data.get("next_page_token")
    if not next_page_token:
        break

# Create a dataframe from the results
pagetwo_df = pd.DataFrame(columns=["Name", "Address"])

for result in results:
    name = result["name"]
    address = result["vicinity"]
    pagetwo_df = pd.concat([pagetwo_df, pd.DataFrame({"Name": [name], "Address": [address]})], ignore_index=True)

# Display the dataframe
pagetwo_df
# Out:
#                                             Name  \
# 0                                 Target Grocery
# 1                                Chico's Mercado
# 2                                   Lucky Market
# 3                               Gold Star Market
# 4                          Dollar General Market
# 5                                    Silo Market
# 6                       The Turnip Truck - Gulch
# 7                        Hunter's Hometown Foods
# 8                                  Silva produce
# 9   Publix Super Market at Hill Center Greenwood
# 10                       Robertson Avenue Market
# 11                Publix Super Market at Melrose
# 12                                Sjj Market Inc
# 13                              K&S World Market
# 14                          Thompson Lane Market
# 15                                          ALDI
# 16                                Target Grocery
# 17      Azadi International Food Market & Bakery
# ...

# %%
response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{\n   "html_attributions" : [],\n   "results" : [\n      {\n         "business_status" : "OPERATIONAL",\n         "geometry" : {\n            "location" : {\n               "lat" : 36.1312093,\n               "lng" : -86.85419890000001\n            },\n            "viewport" : {\n               "northeast" : {\n                  "lat" : 36.13228112989272,\n                  "lng" : -86.85307077010728\n               },\n               "southwest" : {\n                  "lat" : 36.12958147010728,\n                  "lng" : -86.85577042989273\n               }\n            }\n         },\n         "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",\n         "icon_background_color" : "#4B96F3",\n         "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet",\n         "name" : "Target Grocery",\n         "opening_hours" : {\n            "open_now" : true\n         },\n         "photos" : [\n            {\
# ...

# %%
combined_df = pd.concat([pageone_df, pagetwo_df], ignore_index=True)

# %%
combined_df
# Out:
#                                             Name  \
# 0                       Garden Fresh Food Market
# 1                           H G Hill Food Stores
# 2                                      Food Lion
# 3                                   Trader Joe's
# 4                               The Fresh Market
# 5                    Walmart Neighborhood Market
# 6                                      Food Lion
# 7                          Downtown Fresh Market
# 8                                         Kroger
# 9                                      Food Lion
# 10                            Whole Foods Market
# 11                            Lawrence Foods Inc
# 12                                     Food Lion
# 13                                Swett's Market
# 14                      Madison Inglewood Market
# 15                                    Save A Lot
# 16                             Savi Urban Market
# 17                        Resha's Bi-Rite Market
# ...
